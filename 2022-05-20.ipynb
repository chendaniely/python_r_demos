# %%
import pandas as pd
# pip install openpyxl

# %%
pd.read_excel("./data/cmv.xlsx")
# Out:
#     ID  age  prior.radiation  aKIRs  cmv      donor_negative  \
# 0    1   61                0      1    1  recipient_positive
# 1    2   62                1      5    0  recipient_negative
# 2    3   63                0      3    0                 NaN
# 3    4   33                1      2    0  recipient_positive
# 4    5   54                0      6    0                 NaN
# ..  ..  ...              ...    ...  ...                 ...
# 59  60   41                1      2    0  recipient_positive
# 60  61   57                0      2    1                 NaN
# 61  62   61                0      5    0                 NaN
# 62  63   50                0      5    0  recipient_negative
# 63  64   64                0      4    0                 NaN
#
#         donor_positive
# 0                  NaN
# 1                  NaN
# 2   recipient_positive
# 3                  NaN
# 4   recipient_positive
# ..                 ...
# 59                 NaN
# 60  recipient_positive
# ...

# %%
dat = pd.read_excel("./data/cmv.xlsx")

# %%
pip install pyprojroot
# Out:
# ...
#
# ...

# %%
from pyprojroot import here
dat = pd.read_excel(here("./data/cmv.xlsx"))

# %%
here("./data/cmv.xlsx")
# Out:
# WindowsPath('C:/Users/Danie/git/hub/python_r_demos/data/cmv.xlsx')

# %%
dat.loc[dat["cmv"] == 1, ["ID", "cmv"]]
# Out:
#     ID  cmv
# 0    1    1
# 5    6    1
# 8    9    1
# 12  13    1
# 13  14    1
# 15  16    1
# 16  17    1
# 19  20    1
# 26  27    1
# 27  28    1
# 29  30    1
# 30  31    1
# 31  32    1
# 35  36    1
# 36  37    1
# 38  39    1
# 39  40    1
# 40  41    1
# 41  42    1
# 42  43    1
# 44  45    1
# 45  46    1
# 52  53    1
# 53  54    1
# 57  58    1
# 60  61    1
